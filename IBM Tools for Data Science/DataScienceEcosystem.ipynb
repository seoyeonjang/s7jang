# %% [markdown]
# # Data Science Tools and Ecosystem
#
# ![2-title.PNG](attachment:0608b69f-7069-4a1e-b09f-2aab4278d6c6.PNG)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
#
# ![3-intro.PNG](attachment:d008998d-5d70-4d03-889c-9a01cacab322.PNG)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. Java
#
# ![4-dslanguages.PNG](attachment:87af0742-30a4-4287-a44a-c3f5be4e1ba4.PNG)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. TensorFlow
# 2. NumPy
# 3. PyTorch
#
# ![5-dslibraries.PNG](attachment:4e9dbe9c-90b7-4a36-ac35-c5a030fffdd8.PNG)

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |RStudio|
# |Microsoft Azure|
# |Apache|
#
# ![6-dstools.PNG](attachment:100fa3ef-f05a-4554-a8d8-6a15801c9020.PNG)

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python.
#
# ![7-introarithmetic.PNG](attachment:2aed7130-d5b5-43b0-b049-25970d6e94f5.PNG)

# %%
# This is a simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.PNG](attachment:71f78c1d-facf-46b4-aea8-c970d03b4064.PNG)

# %%
# This will convert 200 minutes to hours by dividing by 60. 
minutes = 200
hours = minutes/60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes.PNG](attachment:fec858b2-df6d-4b54-bd5a-1b25e2cbda41.PNG)

# %% [markdown]
# **Objectives:**
# - List popular programming languages for Data Science.
# - List popular libraries for Data Science.
# - List popular tools for Data Science.
# - Create a code to perform a simple arithmetic calculation.
#
#   ![10-objectives.PNG](attachment:a7efb770-6e7a-4edf-beb7-de21338367d4.PNG)

# %% [markdown]
# ## Author
# Seoyeon Jang
#
# ![11-authordetails.PNG](attachment:18da36ef-c2d0-450a-8fc6-cbe5ca8b5fcc.PNG)
